# %%
DF_PATH = "../data/processed/cleaned_data.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageHaveWorkedWith',
                  'DatabaseHaveWorkedWith',
                  #'PlatformHaveWorkedWith',
                  'WebframeHaveWorkedWith',
                  'MiscTechHaveWorkedWith',
                  'ToolsTechHaveWorkedWith',
                  'NEWCollabToolsHaveWorkedWith']

MLFLOW_TRACKING_URI = "../models/mlruns"
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL = "data.pkl"
LOG_MODEL_PKL = "model.pkl"
LOG_METRICS_PKL = "metrics.pkl"

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.tracking import MlflowClient
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import  accuracy_score, f1_score, precision_score, recall_score
import os
import pickle
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
def calc_quality(ground_truth , predictions , metric_func , sort_values = False):
    quality_scores ={}
    for col in predictions.columns:
        role_pred = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        quality_scores[col] = round(metric_func(role_truth , role_pred)*100 , 2)

    quality_scores = pd.Series(quality_scores.values() , index = quality_scores.keys())

    if sort_values:
        quality_scores = quality_scores.sort_values()

    return quality_scores

# %%
df = pd.read_pickle(DF_PATH)
df
# Out:
#                   DevType                           \
#       Academic researcher Data or business analyst
# 0                       0                        0
# 3                       0                        0
# 4                       0                        0
# 8                       0                        0
# 9                       0                        0
# ...                   ...                      ...
# 83434                   0                        0
# 83435                   0                        0
# 83436                   0                        0
# 83437                   0                        0
# 83438                   0                        0
#
#                                                                             \
#       Data scientist or machine learning specialist Database administrator
# 0                                                 0                      0
# 3                                                 0                      0
# 4                                                 0                      0
# 8                                                 0                      0
# 9                                                 1                      0
# ...                                             ...                    ...
# 83434                                             0                      0
# 83435                                             0                      0
# 83436                                             1                      0
# 83437                                             0                      0
# 83438                                             0                      0
#
#                                                                    \
#       DevOps specialist Developer, QA or test Developer, back-end
# 0                     0                     0                   0
# 3                     0                     0                   0
# 4                     0                     0                   0
# 8                     0                     0                   0
# 9                     0                     0                   0
# ...                 ...                   ...                 ...
# 83434                 0                     0                   1
# 83435                 0                     0                   0
# 83436                 1                     0                   0
# 83437                 0                     0                   1
# 83438                 0                     0                   1
#
#                                                      \
#       Developer, desktop or enterprise applications
# 0                                                 0
# 3                                                 0
# 4                                                 1
# 8                                                 0
# 9                                                 0
# ...                                             ...
# 83434                                             0
# 83435                                             0
# 83436                                             0
# 83437                                             0
# 83438                                             0
#
#                                                                         ...  \
#       Developer, embedded applications or devices Developer, front-end  ...
# 0                                               0                    0  ...
# 3                                               0                    1  ...
# 4                                               0                    0  ...
# 8                                               0                    1  ...
# 9                                               0                    0  ...
# ...                                           ...                  ...  ...
# 83434                                           0                    0  ...
# 83435                                           0                    0  ...
# 83436                                           0                    0  ...
# 83437                                           0                    0  ...
# 83438                                           0                    1  ...
#
#       skills_clusters                                                \
#       skills_group_18 skills_group_19 skills_group_2 skills_group_3
# 0                   0               0              0              0
# 3                   2               0              0              0
# 4                   0               0              0              3
# 8                   0               0              0              0
# 9                   0               0              0              6
# ...               ...             ...            ...            ...
# 83434               0               0              0              0
# 83435               0               1              0              0
# 83436               0               0              0              4
# 83437               0               0              0              4
# 83438               1               0              2              0
#
#                                                                    \
#       skills_group_4 skills_group_5 skills_group_6 skills_group_7
# 0                  0              0              0              4
# 3                  0              0              0              0
# 4                  1              2              3              0
# 8                  1              0              3              0
# 9                  0              0              1              0
# ...              ...            ...            ...            ...
# 83434              3              1              0              0
# 83435              4              2              2              4
# 83436              5              1              4              0
# 83437              1              0              4              0
# 83438              4              1              0              0
#
#
#       skills_group_8 skills_group_9
# 0                  2              0
# 3                  2              0
# 4                  1              0
# 8                  2              0
# 9                  1              0
# ...              ...            ...
# 83434              1              1
# 83435              2              1
# 83436              1              0
# 83437              1              0
# 83438              3              0
#
# [46412 rows x 161 columns]

# %%
roles_df = df['DevType'].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1708
# Data or business analyst                          1658
# Data scientist or machine learning specialist     2460
# Database administrator                            1210
# DevOps specialist                                 3056
# Developer, QA or test                             1135
# Developer, back-end                              17084
# Developer, desktop or enterprise applications     4845
# Developer, embedded applications or devices       2138
# Developer, front-end                              8932
# Developer, full-stack                            20655
# Developer, game or graphics                        899
# Developer, mobile                                 4751
# Engineer, data                                    1941
# Scientist                                         1046
# System administrator                              2069
# dtype: int64

# %%
#Resample roles
samples_per_class = 1200
resampled_roles = []

for role_col in roles_df.columns:
    sub_df = roles_df.loc[roles_df[role_col] == 1].copy()

    if len(sub_df) < samples_per_class:
        #Upsample
        sub_df = sub_df.sample(samples_per_class , replace= True , random_state =0)
    
    else:
        #downsample
        sub_df = sub_df.sample(samples_per_class , random_state =0)

    resampled_roles.append(sub_df)

# %%
roles_df = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()

# %%
roles_df.sum(axis=0)
# Out:
# Academic researcher                              2280
# Data or business analyst                         1965
# Data scientist or machine learning specialist    2576
# Database administrator                           1765
# DevOps specialist                                2170
# Developer, QA or test                            1514
# Developer, back-end                              5710
# Developer, desktop or enterprise applications    2690
# Developer, embedded applications or devices      1773
# Developer, front-end                             2614
# Developer, full-stack                            5602
# Developer, game or graphics                      1441
# Developer, mobile                                2155
# Engineer, data                                   2046
# Scientist                                        1910
# System administrator                             2110
# dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop("DevType", axis=1),df["DevType"],random_state=0)
# Out:
# C:\Users\20111\AppData\Local\Temp\ipykernel_22220\2644036712.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, Y_train, Y_test = train_test_split(df.drop("DevType", axis=1),df["DevType"],random_state=0)

# %% [markdown]
# ### Train models

# %%
#intialize mlflow client and experiment
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()
#mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
# Out:
# c:\Users\20111\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:177: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri, store_uri)

# %% [markdown]
# ### Vanilla Forest

# %%
rf_clf = make_pipeline(RobustScaler(),
                    PCA(n_components=0.95),
                    RandomForestClassifier(n_jobs=8 , verbose=1 ,random_state=0))
rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    6.1s finished
# Pipeline(steps=[('robustscaler', RobustScaler()),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=8, random_state=0, verbose=1))])

# %%
# Evaluate on train set
predictions =  pd.DataFrame(rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calc_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
print(train_scores.mean())
train_scores.sort_values("precision_score")
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# accuracy_score     99.971875
# precision_score    99.920625
# recall_score       99.819375
# f1_score           99.869375
# dtype: float64
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.3s finished
#                                                accuracy_score  \
# Scientist                                               99.93
# Developer, QA or test                                   99.96
# Data scientist or machine learning specialist           99.95
# Database administrator                                  99.98
# Academic researcher                                     99.96
# Developer, game or graphics                             99.97
# Data or business analyst                                99.97
# Developer, mobile                                       99.99
# Developer, desktop or enterprise applications           99.98
# Developer, back-end                                     99.97
# Developer, full-stack                                   99.99
# DevOps specialist                                       99.98
# Developer, embedded applications or devices             99.97
# Developer, front-end                                    99.99
# Engineer, data                                          99.98
# System administrator                                    99.98
#
#                                                precision_score  recall_score  \
# Scientist                                                99.65         99.65
# Developer, QA or test                                    99.82         99.64
# Data scientist or machine learning specialist            99.84         99.79
# Database administrator                                   99.85         99.92
# Academic researcher                                      99.88         99.77
# Developer, game or graphics                              99.91         99.63
# Data or business analyst                                 99.93         99.80
# Developer, mobile                                        99.94        100.00
# Developer, desktop or enterprise applications            99.95         99.90
# Developer, back-end                                      99.98         99.93
# Developer, full-stack                                    99.98         99.98
# DevOps specialist                                       100.00         99.82
# Developer, embedded applications or devices             100.00         99.71
# Developer, front-end                                    100.00         99.95
# Engineer, data                                          100.00         99.81
# System administrator                                    100.00         99.81
#
#                                                f1_score
# Scientist                                         99.65
# Developer, QA or test                             99.73
# Data scientist or machine learning specialist     99.82
# Database administrator                            99.89
# Academic researcher                               99.83
# Developer, game or graphics                       99.77
# Data or business analyst                          99.86
# Developer, mobile                                 99.97
# Developer, desktop or enterprise applications     99.93
# Developer, back-end                               99.95
# Developer, full-stack                             99.98
# DevOps specialist                                 99.91
# Developer, embedded applications or devices       99.85
# Developer, front-end                              99.97
# Engineer, data                                    99.90
# System administrator                              99.90

# %%
# Evaluate on test set
predictions =  pd.DataFrame(rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calc_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
print(test_scores.mean())
test_scores.sort_values("precision_score")
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.1s finished
# accuracy_score     92.56625
# precision_score    94.34750
# recall_score       49.55375
# f1_score           63.86375
# dtype: float64
#                                                accuracy_score  \
# Developer, full-stack                                   82.62
# Developer, back-end                                     78.71
# Developer, front-end                                    89.29
# Data scientist or machine learning specialist           93.94
# Developer, desktop or enterprise applications           90.85
# Academic researcher                                     94.94
# Developer, mobile                                       94.69
# DevOps specialist                                       92.75
# Data or business analyst                                94.52
# Developer, embedded applications or devices             94.62
# Scientist                                               97.21
# Developer, game or graphics                             98.00
# Database administrator                                  94.98
# Engineer, data                                          93.92
# Developer, QA or test                                   96.54
# System administrator                                    93.48
#
#                                                precision_score  recall_score  \
# Developer, full-stack                                    77.65         56.65
# Developer, back-end                                      85.08         34.96
# Developer, front-end                                     90.05         28.80
# Data scientist or machine learning specialist            90.11         61.88
# Developer, desktop or enterprise applications            93.22         34.21
# Academic researcher                                      94.08         60.07
# Developer, mobile                                        94.29         55.62
# DevOps specialist                                        96.04         36.33
# Data or business analyst                                 97.48         47.44
# Developer, embedded applications or devices              97.59         38.94
# Scientist                                                97.63         74.75
# Developer, game or graphics                              98.22         75.20
# Database administrator                                   99.02         45.93
# Engineer, data                                           99.53         42.03
# Developer, QA or test                                    99.57         58.23
# System administrator                                    100.00         41.82
#
#                                                f1_score
# Developer, full-stack                             65.51
# Developer, back-end                               49.56
# Developer, front-end                              43.64
# Data scientist or machine learning specialist     73.38
# Developer, desktop or enterprise applications     50.06
# Academic researcher                               73.33
# Developer, mobile                                 69.96
# DevOps specialist                                 52.72
# Data or business analyst                          63.82
# Developer, embedded applications or devices       55.67
# Scientist                                         84.67
# Developer, game or graphics                       85.19
# Database administrator                            62.75
# Engineer, data                                    59.10
# Developer, QA or test                             73.48
# System administrator                              58.98

# %% [markdown]
# ### Log

# %%
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices": X_test.index.tolist(),
                "features_names": X_train.columns.droplevel(0).tolist(),
                "targets_names": Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
model = {"model_description": "Random Forest: with PCA - Basic",
         "model_details": str(rf_clf),
         "model_object": rf_clf}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
classes_metrics = {"train_scores": train_scores,
                   "test_scores": test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    for metric, score in test_scores.mean().items():
        mlflow.log_metric(metric, score)

# %%
hpt_rf_clf = make_pipeline(RobustScaler(),
                           PCA(),
                           RandomForestClassifier(n_jobs=8,verbose=1,
random_state=0))

# %%
tuned_parameters = [{
    'pca__n_components': [0.7, 0.85, 0.95],
    'randomforestclassifier__n_estimators': [250, 500],
    'randomforestclassifier__max_depth':    [3, 10, None],
}]

# %%
hpt_rf_clf = GridSearchCV(hpt_rf_clf, tuned_parameters)
hpt_rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   17.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   12.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   25.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   25.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   24.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   26.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   24.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.6s finished
# GridSearchCV(estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(n_jobs=8,
#                                                                random_state=0,
#                                                                verbose=1))]),
#              param_grid=[{'pca__n_components': [0.7, 0.85, 0.95],
#                           'randomforestclassifier__max_depth': [3, 10, None],
#                           'randomforestclassifier__n_estimators': [250, 500]}])

# %%
hpt_rf_clf.best_params_
# Out:
# {'pca__n_components': 0.7,
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__n_estimators': 500}

# %%
#Evaluate on train set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calc_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.4s finished

# %%
print(train_scores.mean())
train_scores
# Out:
# accuracy_score     99.973125
# precision_score    99.940000
# recall_score       99.808125
# f1_score           99.873750
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     99.96
# Data or business analyst                                99.97
# Data scientist or machine learning specialist           99.96
# Database administrator                                  99.98
# DevOps specialist                                       99.98
# Developer, QA or test                                   99.97
# Developer, back-end                                     99.97
# Developer, desktop or enterprise applications           99.98
# Developer, embedded applications or devices             99.97
# Developer, front-end                                    99.99
# Developer, full-stack                                   99.99
# Developer, game or graphics                             99.97
# Developer, mobile                                       99.99
# Engineer, data                                          99.98
# Scientist                                               99.93
# System administrator                                    99.98
#
#                                                precision_score  recall_score  \
# Academic researcher                                      99.88         99.77
# Data or business analyst                                 99.93         99.80
# Data scientist or machine learning specialist           100.00         99.69
# Database administrator                                   99.92         99.85
# DevOps specialist                                       100.00         99.82
# Developer, QA or test                                    99.82         99.73
# Developer, back-end                                     100.00         99.91
# Developer, desktop or enterprise applications            99.95         99.90
# Developer, embedded applications or devices             100.00         99.71
# Developer, front-end                                    100.00         99.95
# Developer, full-stack                                    99.95        100.00
# Developer, game or graphics                             100.00         99.53
# Developer, mobile                                        99.94        100.00
# Engineer, data                                          100.00         99.81
# Scientist                                                99.65         99.65
# System administrator                                    100.00         99.81
#
#                                                f1_score
# Academic researcher                               99.83
# Data or business analyst                          99.86
# Data scientist or machine learning specialist     99.84
# Database administrator                            99.89
# DevOps specialist                                 99.91
# Developer, QA or test                             99.78
# Developer, back-end                               99.95
# Developer, desktop or enterprise applications     99.93
# Developer, embedded applications or devices       99.85
# Developer, front-end                              99.97
# Developer, full-stack                             99.98
# Developer, game or graphics                       99.77
# Developer, mobile                                 99.97
# Engineer, data                                    99.90
# Scientist                                         99.65
# System administrator                              99.90

# %%
#Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calc_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.5s finished

# %%
print(test_scores.mean())
test_scores
# Out:
# accuracy_score     92.735625
# precision_score    90.820000
# recall_score       52.969375
# f1_score           65.990000
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     94.75
# Data or business analyst                                94.54
# Data scientist or machine learning specialist           94.25
# Database administrator                                  94.94
# DevOps specialist                                       93.06
# Developer, QA or test                                   96.52
# Developer, back-end                                     79.25
# Developer, desktop or enterprise applications           90.92
# Developer, embedded applications or devices             94.83
# Developer, front-end                                    89.50
# Developer, full-stack                                   83.71
# Developer, game or graphics                             97.92
# Developer, mobile                                       95.02
# Engineer, data                                          93.98
# Scientist                                               97.06
# System administrator                                    93.52
#
#                                                precision_score  recall_score  \
# Academic researcher                                      90.43         61.15
# Data or business analyst                                 93.82         49.69
# Data scientist or machine learning specialist            86.90         67.59
# Database administrator                                   98.07         45.93
# DevOps specialist                                        91.02         41.76
# Developer, QA or test                                    99.14         58.23
# Developer, back-end                                      77.50         43.18
# Developer, desktop or enterprise applications            88.19         37.17
# Developer, embedded applications or devices              91.58         44.47
# Developer, front-end                                     82.35         34.44
# Developer, full-stack                                    74.88         66.31
# Developer, game or graphics                              99.26         73.30
# Developer, mobile                                        90.63         61.61
# Engineer, data                                           97.33         43.63
# Scientist                                                94.92         75.56
# System administrator                                     97.10         43.49
#
#                                                f1_score
# Academic researcher                               72.96
# Data or business analyst                          64.97
# Data scientist or machine learning specialist     76.04
# Database administrator                            62.56
# DevOps specialist                                 57.25
# Developer, QA or test                             73.37
# Developer, back-end                               55.46
# Developer, desktop or enterprise applications     52.30
# Developer, embedded applications or devices       59.87
# Developer, front-end                              48.57
# Developer, full-stack                             70.33
# Developer, game or graphics                       84.33
# Developer, mobile                                 73.36
# Engineer, data                                    60.25
# Scientist                                         84.14
# System administrator                              60.08

# %%
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
model = {"model_description": "Random Forest: with PCA + Hyperparamter tuning",
         "model_details": str(hpt_rf_clf),
         "model_object": hpt_rf_clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id, 
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)  
    
    # Track metrics 
    for metric, score in test_scores.mean().items():
        mlflow.log_metric(metric, score)
