# %%
DF_PATH = "../data/processed/cleaned_data.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageHaveWorkedWith',
                  'DatabaseHaveWorkedWith',
                  'PlatformHaveWorkedWith',
                  'WebframeHaveWorkedWith',
                  'MiscTechHaveWorkedWith',
                  'ToolsTechHaveWorkedWith',
                  'NEWCollabToolsHaveWorkedWith']

MLFLOW_TRACKING_URI = "../models/mlruns"
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL = "data.pkl"
LOG_MODEL_PKL = "model.pkl"
LOG_METRICS_PKL = "metrics.pkl"

# %%
import pandas as pd

# %%
def calc_quality(ground_truth , predictions , metric_func , sort_values = False):
    quality_scores ={}
    for col in predictions.columns:
        role_pred = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        quality_scores[col] = round(metric_func(role_truth , role_pred)*100 , 2)

    quality_scores = pd.Series(quality_scores.values() , index = quality_scores.keys())

    if sort_values:
        quality_scores = quality_scores.sort_values()

    return quality_scores

# %%
#create directories
from pathlib import Path
Path(MLFLOW_TRACKING_URI).mkdir(parents=True , exist_ok=True)
Path(LOG_PATH).mkdir(parents=True , exist_ok=True)

# %%
df = pd.read_pickle(DF_PATH)
df
# Out:
#                   DevType                           \
#       Academic researcher Data or business analyst
# 0                       0                        0
# 3                       0                        0
# 4                       0                        0
# 8                       0                        0
# 9                       0                        0
# ...                   ...                      ...
# 83434                   0                        0
# 83435                   0                        0
# 83436                   0                        0
# 83437                   0                        0
# 83438                   0                        0
#
#                                                                             \
#       Data scientist or machine learning specialist Database administrator
# 0                                                 0                      0
# 3                                                 0                      0
# 4                                                 0                      0
# 8                                                 0                      0
# 9                                                 1                      0
# ...                                             ...                    ...
# 83434                                             0                      0
# 83435                                             0                      0
# 83436                                             1                      0
# 83437                                             0                      0
# 83438                                             0                      0
#
#                                                                    \
#       DevOps specialist Developer, QA or test Developer, back-end
# 0                     0                     0                   0
# 3                     0                     0                   0
# 4                     0                     0                   0
# 8                     0                     0                   0
# 9                     0                     0                   0
# ...                 ...                   ...                 ...
# 83434                 0                     0                   1
# 83435                 0                     0                   0
# 83436                 1                     0                   0
# 83437                 0                     0                   1
# 83438                 0                     0                   1
#
#                                                      \
#       Developer, desktop or enterprise applications
# 0                                                 0
# 3                                                 0
# 4                                                 1
# 8                                                 0
# 9                                                 0
# ...                                             ...
# 83434                                             0
# 83435                                             0
# 83436                                             0
# 83437                                             0
# 83438                                             0
#
#                                                                         ...  \
#       Developer, embedded applications or devices Developer, front-end  ...
# 0                                               0                    0  ...
# 3                                               0                    1  ...
# 4                                               0                    0  ...
# 8                                               0                    1  ...
# 9                                               0                    0  ...
# ...                                           ...                  ...  ...
# 83434                                           0                    0  ...
# 83435                                           0                    0  ...
# 83436                                           0                    0  ...
# 83437                                           0                    0  ...
# 83438                                           0                    1  ...
#
#       skills_clusters                                                \
#       skills_group_18 skills_group_19 skills_group_2 skills_group_3
# 0                   0               0              0              0
# 3                   2               0              0              0
# 4                   0               0              0              3
# 8                   0               0              0              0
# 9                   0               0              0              6
# ...               ...             ...            ...            ...
# 83434               0               0              0              0
# 83435               0               1              0              0
# 83436               0               0              0              4
# 83437               0               0              0              4
# 83438               1               0              2              0
#
#                                                                    \
#       skills_group_4 skills_group_5 skills_group_6 skills_group_7
# 0                  0              0              0              4
# 3                  0              0              0              0
# 4                  1              2              3              0
# 8                  1              0              3              0
# 9                  0              0              1              0
# ...              ...            ...            ...            ...
# 83434              3              1              0              0
# 83435              4              2              2              4
# 83436              5              1              4              0
# 83437              1              0              4              0
# 83438              4              1              0              0
#
#
#       skills_group_8 skills_group_9
# 0                  2              0
# 3                  2              0
# 4                  1              0
# 8                  2              0
# 9                  1              0
# ...              ...            ...
# 83434              1              1
# 83435              2              1
# 83436              1              0
# 83437              1              0
# 83438              3              0
#
# [46412 rows x 161 columns]

# %% [markdown]
# ### Balance classes

# %%
roles_df = df['DevType'].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1708
# Data or business analyst                          1658
# Data scientist or machine learning specialist     2460
# Database administrator                            1210
# DevOps specialist                                 3056
# Developer, QA or test                             1135
# Developer, back-end                              17084
# Developer, desktop or enterprise applications     4845
# Developer, embedded applications or devices       2138
# Developer, front-end                              8932
# Developer, full-stack                            20655
# Developer, game or graphics                        899
# Developer, mobile                                 4751
# Engineer, data                                    1941
# Scientist                                         1046
# System administrator                              2069
# dtype: int64

# %%
#Resample roles
samples_per_class = 1200
resampled_roles = []

for role_col in roles_df.columns:
    sub_df = roles_df.loc[roles_df[role_col] == 1].copy()

    if len(sub_df) < samples_per_class:
        #Upsample
        sub_df = sub_df.sample(samples_per_class , replace= True , random_state =0)
    
    else:
        #downsample
        sub_df = sub_df.sample(samples_per_class , random_state =0)

    resampled_roles.append(sub_df)

# %%
roles_df = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()

# %%
roles_df.sum(axis=0)
# Out:
# Academic researcher                              2280
# Data or business analyst                         1965
# Data scientist or machine learning specialist    2576
# Database administrator                           1765
# DevOps specialist                                2170
# Developer, QA or test                            1514
# Developer, back-end                              5710
# Developer, desktop or enterprise applications    2690
# Developer, embedded applications or devices      1773
# Developer, front-end                             2614
# Developer, full-stack                            5602
# Developer, game or graphics                      1441
# Developer, mobile                                2155
# Engineer, data                                   2046
# Scientist                                        1910
# System administrator                             2110
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df.drop("DevType", axis=1),df["DevType"],random_state=0)
# Out:
# C:\Users\20111\AppData\Local\Temp\ipykernel_5512\2452005646.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, Y_train, Y_test = train_test_split(df.drop("DevType", axis=1),df["DevType"],random_state=0)

# %% [markdown]
# ### Train models

# %%
#intialize mlflow client and experiment
import mlflow
from mlflow.tracking import MlflowClient
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()
mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
# Out:
# c:\Users\20111\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:177: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri, store_uri)
# 2025/12/12 01:18:33 INFO mlflow.tracking.fluent: Experiment with name 'skills_jobs_stackoverflow' does not exist. Creating a new experiment.

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline, FeatureUnion
clf = make_pipeline(StandardScaler(),MultiOutputClassifier(LogisticRegression()))

clf.fit(X_train.values , Y_train.values)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('multioutputclassifier',
#                  MultiOutputClassifier(estimator=LogisticRegression()))])

# %%
#Evaluate on training set
from sklearn.metrics import  accuracy_score, f1_score, precision_score, recall_score
predictions = pd.DataFrame(clf.predict(X_train.values) , columns= Y_train.columns)
train_scores = {score.__name__:calc_quality(Y_train , predictions , score) for score in [accuracy_score,  precision_score, recall_score ,f1_score]}
train_scores = pd.concat(train_scores , axis =1)
print(train_scores.mean())
train_scores
# Out:
# accuracy_score     89.066250
# precision_score    65.106250
# recall_score       30.365000
# f1_score           39.291875
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     89.25
# Data or business analyst                                90.69
# Data scientist or machine learning specialist           90.60
# Database administrator                                  90.94
# DevOps specialist                                       90.44
# Developer, QA or test                                   92.24
# Developer, back-end                                     74.33
# Developer, desktop or enterprise applications           86.88
# Developer, embedded applications or devices             92.17
# Developer, front-end                                    88.97
# Developer, full-stack                                   78.78
# Developer, game or graphics                             94.72
# Developer, mobile                                       93.90
# Engineer, data                                          90.19
# Scientist                                               91.09
# System administrator                                    89.87
#
#                                                precision_score  recall_score  \
# Academic researcher                                      61.40         27.49
# Data or business analyst                                 62.96         22.22
# Data scientist or machine learning specialist            71.10         50.16
# Database administrator                                   56.16          6.20
# DevOps specialist                                        67.02         31.30
# Developer, QA or test                                    56.25          0.80
# Developer, back-end                                      61.80         35.35
# Developer, desktop or enterprise applications            62.98         18.61
# Developer, embedded applications or devices              66.29         34.34
# Developer, front-end                                     65.81         36.14
# Developer, full-stack                                    66.80         54.33
# Developer, game or graphics                              75.24         43.58
# Developer, mobile                                        78.96         62.49
# Engineer, data                                           64.93         18.59
# Scientist                                                60.12         27.70
# System administrator                                     63.88         16.54
#
#                                                f1_score
# Academic researcher                               37.98
# Data or business analyst                          32.85
# Data scientist or machine learning specialist     58.82
# Database administrator                            11.16
# DevOps specialist                                 42.67
# Developer, QA or test                              1.59
# Developer, back-end                               44.98
# Developer, desktop or enterprise applications     28.73
# Developer, embedded applications or devices       45.24
# Developer, front-end                              46.66
# Developer, full-stack                             59.92
# Developer, game or graphics                       55.19
# Developer, mobile                                 69.77
# Engineer, data                                    28.90
# Scientist                                         37.93
# System administrator                              26.28

# %%
#Evaluate on test set
predictions = pd.DataFrame(clf.predict(X_test.values) , columns= Y_test.columns)
test_scores = {score.__name__:calc_quality(Y_test , predictions , score) for score in [accuracy_score,  precision_score, recall_score ,f1_score]}
test_scores = pd.concat(test_scores , axis =1)
print(test_scores.mean())
test_scores
# Out:
# accuracy_score     88.937500
# precision_score    62.178125
# recall_score       29.886875
# f1_score           38.608125
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     90.06
# Data or business analyst                                91.12
# Data scientist or machine learning specialist           89.96
# Database administrator                                  90.90
# DevOps specialist                                       90.23
# Developer, QA or test                                   91.69
# Developer, back-end                                     74.40
# Developer, desktop or enterprise applications           87.52
# Developer, embedded applications or devices             92.62
# Developer, front-end                                    88.40
# Developer, full-stack                                   78.48
# Developer, game or graphics                             94.79
# Developer, mobile                                       93.08
# Engineer, data                                          90.25
# Scientist                                               90.12
# System administrator                                    89.38
#
#                                                precision_score  recall_score  \
# Academic researcher                                      64.91         30.94
# Data or business analyst                                 65.99         26.58
# Data scientist or machine learning specialist            67.58         49.23
# Database administrator                                   56.10          5.20
# DevOps specialist                                        65.55         25.66
# Developer, QA or test                                    25.00          0.51
# Developer, back-end                                      62.64         35.72
# Developer, desktop or enterprise applications            61.58         18.20
# Developer, embedded applications or devices              64.62         32.93
# Developer, front-end                                     67.91         36.76
# Developer, full-stack                                    65.53         55.08
# Developer, game or graphics                              76.47         46.05
# Developer, mobile                                        74.75         57.12
# Engineer, data                                           61.18         18.53
# Scientist                                                54.75         24.44
# System administrator                                     60.29         15.24
#
#                                                f1_score
# Academic researcher                               41.90
# Data or business analyst                          37.90
# Data scientist or machine learning specialist     56.96
# Database administrator                             9.52
# DevOps specialist                                 36.88
# Developer, QA or test                              0.99
# Developer, back-end                               45.50
# Developer, desktop or enterprise applications     28.09
# Developer, embedded applications or devices       43.63
# Developer, front-end                              47.70
# Developer, full-stack                             59.85
# Developer, game or graphics                       57.48
# Developer, mobile                                 64.76
# Engineer, data                                    28.44
# Scientist                                         33.80
# System administrator                              24.33

# %% [markdown]
# ### Log run

# %% [markdown]
# ### 1-Prepare

# %%
import os
import pickle
data_details = {
    "data_path" : DF_PATH,
    "training_indicies" : X_train.index.tolist(),
    "test_indicies" : X_test.index.tolist(),
    "feature_names" :  X_train.columns.droplevel(0).tolist(),
    "target_names": Y_train.columns.tolist()
}
with open (os.path.join(LOG_PATH , LOG_DATA_PKL) ,'wb') as output_file:
    pickle.dump(data_details , output_file)

# %%
model = {
    "model_description": "Baseline model: Logistic Regression ",
    "model_details": str(clf),
    "model_object": clf
}

with open (os.path.join(LOG_PATH , LOG_MODEL_PKL) ,'wb') as output_file:
    pickle.dump(model , output_file)

# %%
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %% [markdown]
# ### Log

# %%
#Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id , run_name= model['model_description']):
    mlflow.log_artifacts(LOG_PATH)

    for metric , score in test_scores.mean().items():
        mlflow.log_metric(metric , score)
