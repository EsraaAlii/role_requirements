# %%
API_URL = 'http://127.0.0.1:5000'
PREDICTION_ENDPOINT = '/predict_jobs_probs'
SIMULATION_ENDPOINT = '/recommend_new_skills'

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ### Predict

# %%
available_skills = ['R', 'SQL', 'RStudio']

# %%
predictions = requests.post(API_URL + PREDICTION_ENDPOINT , data = json.dumps(available_skills) , headers ={'content-type':'application/json'})

# %%
pd.Series(predictions.json()).sort_values(ascending=False)
# Out:
# Data or business analyst                         0.69
# Data scientist or machine learning specialist    0.36
# Scientist                                        0.34
# Academic researcher                              0.33
# Database administrator                           0.11
# Developer, desktop or enterprise applications    0.02
# Developer, full-stack                            0.01
# DevOps specialist                                0.00
# Developer, QA or test                            0.00
# Developer, back-end                              0.00
# Developer, embedded applications or devices      0.00
# Developer, front-end                             0.00
# Developer, game or graphics                      0.00
# Developer, mobile                                0.00
# Engineer, data                                   0.00
# System administrator                             0.00
# dtype: float64

# %% [markdown]
# ### Simulate

# %%
target_job = 'Data scientist or machine learning specialist'

# %%
simulations = requests.post(API_URL + SIMULATION_ENDPOINT , data = json.dumps({
    "available_skills":available_skills,
    "target_job" :target_job
}),headers={'content-type':'application/json'})

# %%
pd.Series(simulations.json()).sort_values(ascending=False)
# Out:
# Microsoft SQL Server           1.194444
# AWS                            0.529431
# Oracle                         0.527778
# Keras                          0.472222
# Notepad++                      0.472222
#                                  ...
# Symfony                        0.041667
# Crystal                        0.041667
# COBOL                          0.041667
# Oracle Cloud Infrastructure    0.027778
# ASP.NET                        0.013889
# Length: 78, dtype: float64
